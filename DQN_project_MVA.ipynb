# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import scipy
import io
import base64
from IPython.display import HTML
import skvideo
#skvideo.setFFmpegPath("/anaconda3/lib/python3.6/skvideo")
import skvideo.io
import cv2
import json
from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D,MaxPooling2D,Activation,AveragePooling2D,Reshape,BatchNormalization,Dropout,Flatten, Convolution2D
from keras.utils import np_utils
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
#
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# If we are training our agent we have two options: the first is to act randomly (the goal is to explore the map), the seconod is to follow the policy we have learned (the goal is to improve the policy). Obviously, when we are testing we always follow the policy we have learned.
# Epsilon is essential since it allows us to explore the map and train the agent at the same time.

# %% [markdown]
# ***
# ### The Game

# %%
#The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)

#```python

epoch = 300
env = Environment()
agent = Agent()


# Number of won games
score = 0
loss = 0


for e in range(epoch):
    # At each epoch, we restart to a fresh game and get the initial state
    state = env.reset()
    # This assumes that the games will end
    game_over = False

    win = 0
    lose = 0
    
    while not game_over:
        # The agent performs an action
        action = agent.act(state)

        # Apply an action to the environment, get the next state, the reward
        # and if the games end
        prev_state = state
        state, reward, game_over = env.act(action)

        # Update the counters
        if reward > 0:
            win = win + reward
        if reward < 0:
            lose = lose -reward

        # Apply the reinforcement strategy
        loss = agent.reinforce(prev_state, state,  action, reward, game_over)

    # Save as a mp4
    if e % 10 == 0:
        env.draw(e)

    # Update stats
    score += win-lose

    print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
          .format(e, epoch, loss, win, lose, win-lose))
    agent.save()
#```
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-05bd6570ef18> in <module>()
#      29         # and if the games end
#      30         prev_state = state
# ---> 31         state, reward, game_over = env.act(action)
#      32
#      33         # Update the counters
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the rat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board<0,2] = 256
        b[self.x,self.y,:]= 256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train=True):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:,:] = -1
        self.position[:,-2:] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:,:] = -1
        self.position[:,-2:] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=50
temperature=0.3
epochs_train=10 # set small when debugging
epochs_test=10 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# Board is a matrix whose elements can be 0, +0.5, -1 representing rispectively the presence of nothing, cheese and poisoned cheese.
# Position is a matrix that contains a one in the current position of the rat.
# Note that both matrices have a 2margin to simplify the code.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(0, 4, size=1)[0]

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will end
        game_over = False

        win = 0
        lose = 0
    
        while not game_over:
            # The agent performs an action
            action = agent.learned_act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            state, reward, game_over, reward_1 = env.act(action, False)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

        ##### FILL IN HERE
        
        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 5.5/4.0. Average score (1.5)
# Win/lose count 5.0/6.0. Average score (0.25)
# Win/lose count 1.5/3.0. Average score (-0.3333333333333333)
# Win/lose count 6.0/8.0. Average score (-0.75)
# Win/lose count 3.5/9.0. Average score (-1.7)
# Win/lose count 4.0/6.0. Average score (-1.75)
# Win/lose count 3.5/6.0. Average score (-1.8571428571428572)
# Win/lose count 4.5/3.0. Average score (-1.4375)
# Win/lose count 2.5/5.0. Average score (-1.5555555555555556)
# Win/lose count 2.5/2.0. Average score (-1.35)
# Final score: -1.35
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# __Answer 5.1__
#
# \begin{equation*}
# Q^{\pi}(s,a) = E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] = \sum_{s',a'}{E_{p^{\pi}}[r(s,a) + \gamma\sum_{1 \leq t\leq T}\gamma^{t-1}r(s_{t},a_{t})|s_{0}=s,a_{0}=a, s_{1}=s', a_{1}=a']P(s_{1}=s'|s_{0}=s,a_{0}=a)}\pi(a'|s') = E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# __Answer 5.2__
#
# \begin{equation*}
# Q^{\pi}(s,a) = \sum_{s',a'}{[r(s,a) + \gamma Q^{\pi}(s',a')]P(s_{1}=s'|s_{0}=s,a_{0}=a)}\pi(a'|s') = \sum_{s'}P(s_{1}=s'|s_{0}=s,a_{0}=a){[r(s,a) + \gamma \sum_{a'}\pi(a'|s') Q^{\pi}(s',a')]} \leq \sum_{s'}P(s_{1}=s'|s_{0}=s,a_{0}=a){[r(s,a) + \gamma \max_{a'} Q^{\pi}(s',a')]} = E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{\pi}(s',a')]
# \end{equation*}
#
# and if the policy is optimal we have the equality since we can't improve the optimal policy.
#
# __Answer 5.3__
# We are looking for the optimal policy, i.e. a policy for which it holds:
#
# \begin{equation*}
# E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a') - Q^{*}(s,a)] = 0
# \end{equation*}
#
# So, the choiche of the loss
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}
#
# is reasonable since our neural network will predict the reward for each possible action.

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        if(len(self.memory) < self.max_memory):
            self.memory.append(m)
            self.max_memory += 1
        else:
            self.memory[np.random.randint(len(self.memory))] = m

    def random_access(self):
        return self.memory[np.random.randint(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            
            action = agent.act(state)
                        
            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose - reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16, n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        pass

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size,5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            
            episode = self.memory.random_access()
                        
            if episode[4]:
                ######## FILL IN
                input_states[i] = episode[0]
                target_q[i,:] = self.model.predict(episode[0].reshape((1,5,5,self.n_state)))
                target_q[i,int(episode[2])] = episode[3]
            else:
                ######## FILL IN
                input_states[i] = episode[0]
                target_q[i,:] = self.model.predict(episode[0].reshape((1,5,5,self.n_state)))
                target_q[i,int(episode[2])] = episode[3] + self.discount*int(np.amax(self.model.predict(episode[1].reshape((1,5,5,self.n_state))))) 

        l = self.model.train_on_batch(input_states, target_q)

        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        ####### FILL IN
        
        model = keras.Sequential()
        model.add(Dense(250,activation='relu',input_shape=(5,5,self.n_state)))
        model.add(Dense(1000,activation='relu'))
        model.add(Dense(25,activation='relu'))
        model.add(Flatten())
        model.add(Dense(4,activation='tanh'))
        # We tried relu, linear and softmax. The latter gives the best results.
        # We can interprete it as a probability distribution over the four actions.
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model
        model.summary()
    
    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape((1,5,5,self.n_state))))

# %%
T = 50
epochs_train = 50
env = Environment(grid_size=size, max_time=T, temperature=0.2)
agent = DQN_FC(size, lr=.1, epsilon = 0.4, memory_size=2000, batch_size = 32, n_state=2)
train(agent, env, epochs_train, prefix='fc_train10')
HTML(display_videos('fc_train100.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 5, 5, 250)         750
# _________________________________________________________________
# dense_2 (Dense)              (None, 5, 5, 1000)        251000
# _________________________________________________________________
# dense_3 (Dense)              (None, 5, 5, 25)          25025
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 625)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2504
# =================================================================
# Total params: 279,279
# Trainable params: 279,279
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/050 | Loss 0.0074 | Win/lose count 1.0/0 (1.0)
# Epoch 001/050 | Loss 0.0379 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 002/050 | Loss 0.0132 | Win/lose count 2.0/2.0 (0.0)
# Epoch 003/050 | Loss 0.0116 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 004/050 | Loss 0.0103 | Win/lose count 1.0/1.0 (0.0)
# Epoch 005/050 | Loss 0.0140 | Win/lose count 1.0/0 (1.0)
# Epoch 006/050 | Loss 0.0065 | Win/lose count 2.0/1.0 (1.0)
# Epoch 007/050 | Loss 0.0236 | Win/lose count 1.5/5.0 (-3.5)
# Epoch 008/050 | Loss 0.0314 | Win/lose count 3.0/2.0 (1.0)
# Epoch 009/050 | Loss 0.0154 | Win/lose count 1.5/5.0 (-3.5)
# Epoch 010/050 | Loss 0.0115 | Win/lose count 2.5/2.0 (0.5)
# Epoch 011/050 | Loss 0.0075 | Win/lose count 1.0/1.0 (0.0)
# Epoch 012/050 | Loss 0.0224 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 013/050 | Loss 0.0100 | Win/lose count 2.0/1.0 (1.0)
# Epoch 014/050 | Loss 0.0051 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 015/050 | Loss 0.0080 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 016/050 | Loss 0.0101 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 017/050 | Loss 0.0341 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 018/050 | Loss 0.0208 | Win/lose count 1.0/0 (1.0)
# Epoch 019/050 | Loss 0.0171 | Win/lose count 4.0/4.0 (0.0)
# Epoch 020/050 | Loss 0.0130 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 021/050 | Loss 0.0230 | Win/lose count 2.0/1.0 (1.0)
# Epoch 022/050 | Loss 0.0189 | Win/lose count 5.0/0 (5.0)
# Epoch 023/050 | Loss 0.0044 | Win/lose count 4.0/1.0 (3.0)
# Epoch 024/050 | Loss 0.0051 | Win/lose count 4.5/3.0 (1.5)
# Epoch 025/050 | Loss 0.0097 | Win/lose count 4.5/4.0 (0.5)
# Epoch 026/050 | Loss 0.0063 | Win/lose count 2.0/0 (2.0)
# Epoch 027/050 | Loss 0.0012 | Win/lose count 4.0/1.0 (3.0)
# Epoch 028/050 | Loss 0.0100 | Win/lose count 2.0/2.0 (0.0)
# Epoch 029/050 | Loss 0.0055 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 030/050 | Loss 0.0028 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 031/050 | Loss 0.0017 | Win/lose count 6.0/3.0 (3.0)
# Epoch 032/050 | Loss 0.0028 | Win/lose count 5.0/0 (5.0)
# Epoch 033/050 | Loss 0.0089 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 034/050 | Loss 0.0061 | Win/lose count 3.0/0 (3.0)
# Epoch 035/050 | Loss 0.0026 | Win/lose count 3.5/3.0 (0.5)
# Epoch 036/050 | Loss 0.0032 | Win/lose count 6.5/3.0 (3.5)
# Epoch 037/050 | Loss 0.0055 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 038/050 | Loss 0.0022 | Win/lose count 4.5/1.0 (3.5)
# Epoch 039/050 | Loss 0.0043 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 040/050 | Loss 0.0043 | Win/lose count 1.5/0 (1.5)
# Epoch 041/050 | Loss 0.0023 | Win/lose count 4.0/2.0 (2.0)
# Epoch 042/050 | Loss 0.0031 | Win/lose count 4.5/2.0 (2.5)
# Epoch 043/050 | Loss 0.0018 | Win/lose count 2.0/1.0 (1.0)
# Epoch 044/050 | Loss 0.0033 | Win/lose count 3.0/3.0 (0.0)
# Epoch 045/050 | Loss 0.0013 | Win/lose count 5.5/4.0 (1.5)
# Epoch 046/050 | Loss 0.0014 | Win/lose count 6.5/4.0 (2.5)
# Epoch 047/050 | Loss 0.0015 | Win/lose count 5.5/4.0 (1.5)
# Epoch 048/050 | Loss 0.0015 | Win/lose count 4.5/1.0 (3.5)
# Epoch 049/050 | Loss 0.0016 | Win/lose count 2.5/0 (2.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        ###### FILL IN
        
        nb_actions = 4
        model = Sequential()
        model.add(Convolution2D(32, (2, 2), input_shape=(5,5,self.n_state))) 
        model.add(Convolution2D(64, (2, 2))) 
        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation('relu'))
        model.add(Dense(nb_actions))
        model.add(Activation('tanh')) 
        # We tried relu, linear and softmax. The latter gives the best results.
        # We can interprete it as a probability distribution over the four actions.
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model
        model.summary()
        
    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape((1,5,5,self.n_state))))

# %%
T = 50
epochs_train = 50

env = Environment(grid_size=size, max_time=T, temperature=0.2)
agent = DQN_CNN(size, lr=.1, epsilon = 0.4, memory_size=2000, batch_size = 32, n_state=2)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train0.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 4, 4, 32)          288
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          8256
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              590848
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_2 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 603,492
# Trainable params: 603,492
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/050 | Loss 0.0041 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 001/050 | Loss 0.0019 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 002/050 | Loss 0.0044 | Win/lose count 4.5/1.0 (3.5)
# Epoch 003/050 | Loss 0.0029 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 004/050 | Loss 0.0036 | Win/lose count 2.0/1.0 (1.0)
# Epoch 005/050 | Loss 0.0076 | Win/lose count 2.0/0 (2.0)
# Epoch 006/050 | Loss 0.0055 | Win/lose count 5.0/5.0 (0.0)
# Epoch 007/050 | Loss 0.0033 | Win/lose count 4.0/2.0 (2.0)
# Epoch 008/050 | Loss 0.0018 | Win/lose count 3.0/3.0 (0.0)
# Epoch 009/050 | Loss 0.0029 | Win/lose count 4.0/4.0 (0.0)
# Epoch 010/050 | Loss 0.0025 | Win/lose count 1.0/0 (1.0)
# Epoch 011/050 | Loss 0.0016 | Win/lose count 5.0/2.0 (3.0)
# Epoch 012/050 | Loss 0.0018 | Win/lose count 8.5/2.0 (6.5)
# Epoch 013/050 | Loss 0.0007 | Win/lose count 1.0/1.0 (0.0)
# Epoch 014/050 | Loss 0.0014 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 015/050 | Loss 0.0014 | Win/lose count 7.0/0 (7.0)
# Epoch 016/050 | Loss 0.0020 | Win/lose count 1.0/1.0 (0.0)
# Epoch 017/050 | Loss 0.0021 | Win/lose count 4.0/2.0 (2.0)
# Epoch 018/050 | Loss 0.0066 | Win/lose count 6.5/2.0 (4.5)
# Epoch 019/050 | Loss 0.0031 | Win/lose count 4.0/0 (4.0)
# Epoch 020/050 | Loss 0.0009 | Win/lose count 4.5/3.0 (1.5)
# Epoch 021/050 | Loss 0.0015 | Win/lose count 8.0/0 (8.0)
# Epoch 022/050 | Loss 0.0017 | Win/lose count 5.0/2.0 (3.0)
# Epoch 023/050 | Loss 0.0011 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 024/050 | Loss 0.0006 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 025/050 | Loss 0.0010 | Win/lose count 5.5/1.0 (4.5)
# Epoch 026/050 | Loss 0.0008 | Win/lose count 6.0/1.0 (5.0)
# Epoch 027/050 | Loss 0.0010 | Win/lose count 4.5/2.0 (2.5)
# Epoch 028/050 | Loss 0.0005 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 029/050 | Loss 0.0006 | Win/lose count 3.5/2.0 (1.5)
# Epoch 030/050 | Loss 0.0022 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 031/050 | Loss 0.0011 | Win/lose count 4.5/2.0 (2.5)
# Epoch 032/050 | Loss 0.0013 | Win/lose count 3.0/2.0 (1.0)
# Epoch 033/050 | Loss 0.0014 | Win/lose count 5.0/2.0 (3.0)
# Epoch 034/050 | Loss 0.0007 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 035/050 | Loss 0.0004 | Win/lose count 5.0/1.0 (4.0)
# Epoch 036/050 | Loss 0.0007 | Win/lose count 6.5/2.0 (4.5)
# Epoch 037/050 | Loss 0.0015 | Win/lose count 4.5/2.0 (2.5)
# Epoch 038/050 | Loss 0.0005 | Win/lose count 5.5/1.0 (4.5)
# Epoch 039/050 | Loss 0.0005 | Win/lose count 6.5/2.0 (4.5)
# Epoch 040/050 | Loss 0.0006 | Win/lose count 4.5/2.0 (2.5)
# Epoch 041/050 | Loss 0.0002 | Win/lose count 8.0/3.0 (5.0)
# Epoch 042/050 | Loss 0.0006 | Win/lose count 2.5/1.0 (1.5)
# Epoch 043/050 | Loss 0.0013 | Win/lose count 4.0/2.0 (2.0)
# Epoch 044/050 | Loss 0.0005 | Win/lose count 3.0/1.0 (2.0)
# Epoch 045/050 | Loss 0.0056 | Win/lose count 10.5/2.0 (8.5)
# Epoch 046/050 | Loss 0.0009 | Win/lose count 3.5/2.0 (1.5)
# Epoch 047/050 | Loss 0.0006 | Win/lose count 2.5/1.0 (1.5)
# Epoch 048/050 | Loss 0.0056 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 049/050 | Loss 0.0011 | Win/lose count 3.5/2.0 (1.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.2)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 4, 4, 32)          288
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 64)          8256
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              590848
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 603,492
# Trainable params: 603,492
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 5, 5, 250)         750
# _________________________________________________________________
# dense_10 (Dense)             (None, 5, 5, 1000)        251000
# _________________________________________________________________
# dense_11 (Dense)             (None, 5, 5, 25)          25025
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 625)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 2504
# =================================================================
# Total params: 279,279
# Trainable params: 279,279
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 1.0/1.0. Average score (0.0)
# Win/lose count 0/0. Average score (0.0)
# Win/lose count 2.5/4.0. Average score (-0.5)
# Win/lose count 0/1.0. Average score (-0.625)
# Win/lose count 0.5/3.0. Average score (-1.0)
# Win/lose count 1.5/1.0. Average score (-0.75)
# Win/lose count 0.5/1.0. Average score (-0.7142857142857143)
# Win/lose count 4.5/4.0. Average score (-0.5625)
# Win/lose count 0.5/1.0. Average score (-0.5555555555555556)
# Win/lose count 1.0/1.0. Average score (-0.5)
# Final score: -0.5
# Test of the FC
# Win/lose count 1.0/2.0. Average score (-1.0)
# Win/lose count 0/0. Average score (-0.5)
# Win/lose count 0.5/0. Average score (-0.16666666666666666)
# Win/lose count 1.0/1.0. Average score (-0.125)
# Win/lose count 1.5/1.0. Average score (0.0)
# Win/lose count 0/0. Average score (0.0)
# Win/lose count 0/1.0. Average score (-0.14285714285714285)
# Win/lose count 0/0. Average score (-0.125)
# Win/lose count 1.5/6.0. Average score (-0.6111111111111112)
# Win/lose count 0.5/1.0. Average score (-0.6)
# Final score: -0.6

# %%
HTML(display_videos('cnn_test0.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test0.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# __Answer__
#
# First we fixed the temperature at 0.4. During training: with the first network the agent does not explore very well the map and often turns around the initial position, with the convolutional network the agent explores better the map but still has the tendency to rivist many times some cells. During testing in both cases the agent starts oscillating since the beginning.
#
# Then we increased the temperature at 0.8. During training, in both cases the agent better explores the map since it can follow a path made by only red cases. During testing, in both cases the agent explores just few cases before starting oscillating.
#
# Finally, we fixed the temperature at 0.2. During training we observe the agent's behaviour is very similar to the case with temperature=0.4. During testing: with the first network the agent starts oscillating since the very beginning, with the convolutional network the agent explores just few cases before starting oscillating.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0
    eps = 1
    decay_coeff = 0.99 
    
    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        
        eps = eps*decay_coeff 
        agent.set_epsilon(eps) 
        
        while not game_over:
            # The agent performs an action
            action = agent.act(state)
            
            #agent.set_epsilon(agent.epsilon*decay_coeff)
            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over, reward_1 = env.act(action)

            # Update the counters
            if reward_1 > 0:
                win = round(win + reward_1,2)
                
            if reward_1 < 0:
                lose = round(lose - reward_1,2)

            # Apply the reinforcement strategy
            loss = round(agent.reinforce(prev_state, state, action, reward, game_over), 2)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += round(win-lose,2)
        

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        self.malus_position = np.zeros((grid_size,grid_size))

        # coordinate of the rat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board<0,2] = 256
        b[self.x,self.y,:]= 256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train=True): #train
        """This function returns the new state, reward and decides if the
        game ends."""
        
        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:,:] = -1
        self.position[:,-2:] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        
        reward = 0
        if train: 
            reward = -self.malus_position[self.x, self.y]        
        self.malus_position[self.x, self.y] += 0.5 
        # 0.5 is the value that optimizes the average score. 
        
        reward += self.board[self.x, self.y]
        
        reward_1 = self.board[self.x, self.y]
        
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                        self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
          
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over, reward_1

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]

        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))

        malus[bonus>0]=0

        self.board = bonus + malus
        
        self.malus_position = np.zeros((self.grid_size,self.grid_size))
        
        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:,:] = -1
        self.position[:,-2:] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                        self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
T = 100
epochs_train = 100 
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.4)
agent = DQN_CNN(size, lr=.1, epsilon = 1, memory_size=2000, batch_size = 32, n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore0.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 4, 4, 32)          416
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 64)          8256
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1024)              590848
# _________________________________________________________________
# activation_11 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_12 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 603,620
# Trainable params: 603,620
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/100 | Loss 0.1100 | Win/lose count 6.0/6.0 (0.0)
# Epoch 001/100 | Loss 0.1400 | Win/lose count 8.0/7.0 (1.0)
# Epoch 002/100 | Loss 0.1800 | Win/lose count 3.0/7.0 (-4.0)
# Epoch 003/100 | Loss 0.2900 | Win/lose count 7.0/9.0 (-2.0)
# Epoch 004/100 | Loss 0.1700 | Win/lose count 7.0/13.0 (-6.0)
# Epoch 005/100 | Loss 0.4400 | Win/lose count 4.5/7.0 (-2.5)
# Epoch 006/100 | Loss 0.1100 | Win/lose count 9.5/6.0 (3.5)
# Epoch 007/100 | Loss 0.0800 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 008/100 | Loss 0.2300 | Win/lose count 11.5/9.0 (2.5)
# Epoch 009/100 | Loss 0.1400 | Win/lose count 12.0/7.0 (5.0)
# Epoch 010/100 | Loss 0.1200 | Win/lose count 9.5/10.0 (-0.5)
# Epoch 011/100 | Loss 0.2200 | Win/lose count 8.0/11.0 (-3.0)
# Epoch 012/100 | Loss 0.0800 | Win/lose count 13.5/7.0 (6.5)
# Epoch 013/100 | Loss 0.0100 | Win/lose count 11.5/9.0 (2.5)
# Epoch 014/100 | Loss 0.1300 | Win/lose count 11.5/8.0 (3.5)
# Epoch 015/100 | Loss 0.1500 | Win/lose count 6.5/8.0 (-1.5)
# Epoch 016/100 | Loss 0.2200 | Win/lose count 13.0/8.0 (5.0)
# Epoch 017/100 | Loss 0.1300 | Win/lose count 11.5/13.0 (-1.5)
# Epoch 018/100 | Loss 0.2800 | Win/lose count 8.0/6.0 (2.0)
# Epoch 019/100 | Loss 0.1000 | Win/lose count 10.0/4.0 (6.0)
# Epoch 020/100 | Loss 0.0700 | Win/lose count 7.0/7.0 (0.0)
# Epoch 021/100 | Loss 0.0700 | Win/lose count 10.0/13.0 (-3.0)
# Epoch 022/100 | Loss 0.0200 | Win/lose count 11.5/14.0 (-2.5)
# Epoch 023/100 | Loss 0.0900 | Win/lose count 10.5/8.0 (2.5)
# Epoch 024/100 | Loss 0.0800 | Win/lose count 9.5/13.0 (-3.5)
# Epoch 025/100 | Loss 0.1000 | Win/lose count 10.0/13.0 (-3.0)
# Epoch 026/100 | Loss 0.1500 | Win/lose count 11.5/4.0 (7.5)
# Epoch 027/100 | Loss 0.0200 | Win/lose count 9.0/7.0 (2.0)
# Epoch 028/100 | Loss 0.0300 | Win/lose count 12.0/10.0 (2.0)
# Epoch 029/100 | Loss 0.1000 | Win/lose count 15.5/9.0 (6.5)
# Epoch 030/100 | Loss 0.1100 | Win/lose count 11.0/10.0 (1.0)
# Epoch 031/100 | Loss 0.1600 | Win/lose count 17.0/13.0 (4.0)
# Epoch 032/100 | Loss 0.0300 | Win/lose count 13.5/3.0 (10.5)
# Epoch 033/100 | Loss 0.1200 | Win/lose count 10.5/14.0 (-3.5)
# Epoch 034/100 | Loss 0.0200 | Win/lose count 9.0/6.0 (3.0)
# Epoch 035/100 | Loss 0.0500 | Win/lose count 16.5/9.0 (7.5)
# Epoch 036/100 | Loss 0.0700 | Win/lose count 14.0/5.0 (9.0)
# Epoch 037/100 | Loss 0.1600 | Win/lose count 12.5/10.0 (2.5)
# Epoch 038/100 | Loss 0.0900 | Win/lose count 12.5/13.0 (-0.5)
# Epoch 039/100 | Loss 0.0200 | Win/lose count 10.0/7.0 (3.0)
# Epoch 040/100 | Loss 0.0100 | Win/lose count 8.5/8.0 (0.5)
# Epoch 041/100 | Loss 0.0300 | Win/lose count 9.5/4.0 (5.5)
# Epoch 042/100 | Loss 0.0000 | Win/lose count 16.0/10.0 (6.0)
# Epoch 043/100 | Loss 0.0300 | Win/lose count 8.0/11.0 (-3.0)
# Epoch 044/100 | Loss 0.1400 | Win/lose count 16.5/7.0 (9.5)
# Epoch 045/100 | Loss 0.0600 | Win/lose count 12.0/14.0 (-2.0)
# Epoch 046/100 | Loss 0.0700 | Win/lose count 16.5/6.0 (10.5)
# Epoch 047/100 | Loss 0.0400 | Win/lose count 19.0/15.0 (4.0)
# Epoch 048/100 | Loss 0.2000 | Win/lose count 9.0/7.0 (2.0)
# Epoch 049/100 | Loss 0.0400 | Win/lose count 10.5/5.0 (5.5)
# Epoch 050/100 | Loss 0.2900 | Win/lose count 15.0/13.0 (2.0)
# Epoch 051/100 | Loss 0.0400 | Win/lose count 12.0/10.0 (2.0)
# Epoch 052/100 | Loss 0.0700 | Win/lose count 21.0/10.0 (11.0)
# Epoch 053/100 | Loss 0.0200 | Win/lose count 9.0/4.0 (5.0)
# Epoch 054/100 | Loss 0.0000 | Win/lose count 14.5/5.0 (9.5)
# Epoch 055/100 | Loss 0.0200 | Win/lose count 17.0/9.0 (8.0)
# Epoch 056/100 | Loss 0.0100 | Win/lose count 13.5/11.0 (2.5)
# Epoch 057/100 | Loss 0.1300 | Win/lose count 10.0/10.0 (0.0)
# Epoch 058/100 | Loss 0.0200 | Win/lose count 16.5/8.0 (8.5)
# Epoch 059/100 | Loss 0.0300 | Win/lose count 12.5/10.0 (2.5)
# Epoch 060/100 | Loss 0.0200 | Win/lose count 9.5/10.0 (-0.5)
# Epoch 061/100 | Loss 0.0100 | Win/lose count 13.5/9.0 (4.5)
# Epoch 062/100 | Loss 0.0100 | Win/lose count 10.5/14.0 (-3.5)
# Epoch 063/100 | Loss 0.0400 | Win/lose count 14.5/3.0 (11.5)
# Epoch 064/100 | Loss 0.0000 | Win/lose count 16.5/10.0 (6.5)
# Epoch 065/100 | Loss 0.0100 | Win/lose count 15.5/5.0 (10.5)
# Epoch 066/100 | Loss 0.0300 | Win/lose count 15.5/5.0 (10.5)
# Epoch 067/100 | Loss 0.0200 | Win/lose count 12.5/7.0 (5.5)
# Epoch 068/100 | Loss 0.0400 | Win/lose count 9.5/7.0 (2.5)
# Epoch 069/100 | Loss 0.0800 | Win/lose count 13.0/9.0 (4.0)
# Epoch 070/100 | Loss 0.0100 | Win/lose count 19.5/6.0 (13.5)
# Epoch 071/100 | Loss 0.0000 | Win/lose count 15.0/14.0 (1.0)
# Epoch 072/100 | Loss 0.0100 | Win/lose count 13.0/9.0 (4.0)
# Epoch 073/100 | Loss 0.0300 | Win/lose count 17.5/6.0 (11.5)
# Epoch 074/100 | Loss 0.0800 | Win/lose count 16.0/14.0 (2.0)
# Epoch 075/100 | Loss 0.0200 | Win/lose count 14.0/13.0 (1.0)
# Epoch 076/100 | Loss 0.0800 | Win/lose count 16.0/3.0 (13.0)
# Epoch 077/100 | Loss 0.0200 | Win/lose count 20.0/8.0 (12.0)
# Epoch 078/100 | Loss 0.0100 | Win/lose count 13.5/2.0 (11.5)
# Epoch 079/100 | Loss 0.0000 | Win/lose count 17.5/11.0 (6.5)
# Epoch 080/100 | Loss 0.0000 | Win/lose count 14.0/6.0 (8.0)
# Epoch 081/100 | Loss 0.0200 | Win/lose count 18.0/9.0 (9.0)
# Epoch 082/100 | Loss 0.0500 | Win/lose count 18.0/6.0 (12.0)
# Epoch 083/100 | Loss 0.0100 | Win/lose count 11.5/6.0 (5.5)
# Epoch 084/100 | Loss 0.0700 | Win/lose count 15.0/9.0 (6.0)
# Epoch 085/100 | Loss 0.0300 | Win/lose count 19.5/14.0 (5.5)
# Epoch 086/100 | Loss 0.0100 | Win/lose count 17.5/6.0 (11.5)
# Epoch 087/100 | Loss 0.0900 | Win/lose count 16.5/5.0 (11.5)
# Epoch 088/100 | Loss 0.0400 | Win/lose count 17.5/10.0 (7.5)
# Epoch 089/100 | Loss 0.0300 | Win/lose count 20.0/8.0 (12.0)
# Epoch 090/100 | Loss 0.0100 | Win/lose count 17.5/8.0 (9.5)
# Epoch 091/100 | Loss 0.0200 | Win/lose count 17.5/5.0 (12.5)
# Epoch 092/100 | Loss 0.0600 | Win/lose count 17.0/6.0 (11.0)
# Epoch 093/100 | Loss 0.0500 | Win/lose count 17.0/7.0 (10.0)
# Epoch 094/100 | Loss 0.0200 | Win/lose count 15.0/5.0 (10.0)
# Epoch 095/100 | Loss 0.0400 | Win/lose count 12.0/13.0 (-1.0)
# Epoch 096/100 | Loss 0.0100 | Win/lose count 22.0/10.0 (12.0)
# Epoch 097/100 | Loss 0.0100 | Win/lose count 10.0/8.0 (2.0)
# Epoch 098/100 | Loss 0.0100 | Win/lose count 12.0/7.0 (5.0)
# Epoch 099/100 | Loss 0.0200 | Win/lose count 18.0/10.0 (8.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
epochs_test = 50
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore0.mp4'))
# Out:
# Win/lose count 24.5/2.0. Average score (22.5)
# Win/lose count 23.5/0. Average score (23.0)
# Win/lose count 22.5/3.0. Average score (21.833333333333332)
# Win/lose count 22.0/5.0. Average score (20.625)
# Win/lose count 24.0/1.0. Average score (21.1)
# Win/lose count 24.5/0. Average score (21.666666666666668)
# Win/lose count 23.5/3.0. Average score (21.5)
# Win/lose count 25.5/1.0. Average score (21.875)
# Win/lose count 22.0/0. Average score (21.88888888888889)
# Win/lose count 22.0/3.0. Average score (21.6)
# Win/lose count 20.0/1.0. Average score (21.363636363636363)
# Win/lose count 29.0/1.0. Average score (21.916666666666668)
# Win/lose count 25.0/3.0. Average score (21.923076923076923)
# Win/lose count 17.5/0. Average score (21.607142857142858)
# Win/lose count 22.0/0. Average score (21.633333333333333)
# Win/lose count 22.5/2.0. Average score (21.5625)
# Win/lose count 24.5/0. Average score (21.735294117647058)
# Win/lose count 17.0/2.0. Average score (21.36111111111111)
# Win/lose count 20.5/1.0. Average score (21.263157894736842)
# Win/lose count 28.5/1.0. Average score (21.575)
# Win/lose count 26.0/1.0. Average score (21.738095238095237)
# Win/lose count 28.5/0. Average score (22.045454545454547)
# Win/lose count 20.5/0. Average score (21.97826086956522)
# Win/lose count 23.5/0. Average score (22.041666666666668)
# Win/lose count 23.0/0. Average score (22.08)
# Win/lose count 23.5/1.0. Average score (22.096153846153847)
# Win/lose count 22.5/1.0. Average score (22.074074074074073)
# Win/lose count 24.5/0. Average score (22.160714285714285)
# Win/lose count 19.0/1.0. Average score (22.017241379310345)
# Win/lose count 27.0/4.0. Average score (22.05)
# Win/lose count 24.5/3.0. Average score (22.032258064516128)
# Win/lose count 21.0/2.0. Average score (21.9375)
# Win/lose count 19.5/1.0. Average score (21.833333333333332)
# Win/lose count 18.5/4.0. Average score (21.61764705882353)
# Win/lose count 20.0/3.0. Average score (21.485714285714284)
# Win/lose count 22.5/3.0. Average score (21.430555555555557)
# Win/lose count 24.5/0. Average score (21.513513513513512)
# Win/lose count 20.0/2.0. Average score (21.42105263157895)
# Win/lose count 18.0/4.0. Average score (21.23076923076923)
# Win/lose count 22.5/1.0. Average score (21.2375)
# Win/lose count 26.0/0. Average score (21.353658536585368)
# Win/lose count 26.0/0. Average score (21.464285714285715)
# Win/lose count 26.5/0. Average score (21.58139534883721)
# Win/lose count 20.5/4.0. Average score (21.46590909090909)
# Win/lose count 25.0/1.0. Average score (21.522222222222222)
# Win/lose count 21.5/1.0. Average score (21.5)
# Win/lose count 20.5/3.0. Average score (21.414893617021278)
# Win/lose count 21.5/0. Average score (21.416666666666668)
# Win/lose count 25.5/1.0. Average score (21.479591836734695)
# Win/lose count 23.5/1.0. Average score (21.5)
# Final score: 21.5
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.
